# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
import requests
from PIL import Image
from io import BytesIO
from math import ceil
from wordcloud import WordCloud
from difflib import SequenceMatcher
import spacy

# %%
pd.set_option('max_colwidth', 100)
pd.set_option('display.max_columns', 50)

# %%
raw_data = pd.read_csv('../data/appstore_games.csv')

# %%
raw_data.drop_duplicates(subset='ID', inplace = True)

# %%
dat = raw_data.copy()

# %% [markdown]
# Initial Visualizations

# %% [markdown]
# #### Ratings

# %%
bins = [0,1,2,3,4,5]
pd.cut(dat['Average User Rating'], bins).value_counts().plot(kind = 'bar')
plt.xlabel('Scores')
plt.ylabel('Count')
plt.title('Scores Histogram')
plt.show()

# %%
plt.hist(dat['Average User Rating'].dropna())
plt.xlabel('Scores')
plt.ylabel('Count')
plt.title('Scores Histogram')
plt.show()

# %% [markdown]
# Count of ratings

# %%
plt.hist(dat['User Rating Count'].dropna())
plt.axvline(dat['User Rating Count'].dropna().mean())
plt.show()

# %% [markdown]
# Some outliers making this strange, narrow the scope and look again

# %%
plt.hist(dat[dat['User Rating Count'] < 30000]['User Rating Count'].dropna())
plt.axvline(dat['User Rating Count'].dropna().mean())
plt.show()

# %%
plt.hist(dat[dat['User Rating Count'] < 5000]['User Rating Count'].dropna())
plt.show()

# %% [markdown]
# Most between 0 and 500

# %%
plt.hist(dat[dat['User Rating Count'] < 500]['User Rating Count'].dropna())
plt.show()

# %%
dat['User Rating Count'].dropna().mean()
# Out:
# 3306.2447916666665

# %% [markdown]
# #### Cost

# %%
plt.hist(dat['Price'].dropna())
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Price Histogram')
plt.show()

# %% [markdown]
# Take a closer look at the majority of the data

# %%
plt.hist(dat[dat['Price'] < 25]['Price'].dropna())
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Price Histogram')
plt.show()

# %% [markdown]
# Heavilly skewed to include free games

# %% [markdown]
# Look at non-free and narrow the scope again

# %%
plt.hist(dat[(dat['Price'] < 15) & (dat['Price'] != 0)]['Price'].dropna())
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Price of non-free Apps')
plt.show()

# %%
dat[(dat['Price'] == 0)].shape
# Out:
# (14084, 23)

# %%
dat.shape
# Out:
# (16847, 23)

# %%
14084 / 16847
# Out:
# 0.8359945390870778

# %%
def visualize_raw_dat_ratings():
    dat = pd.read_csv('../data/appstore_games.csv')
    dat.drop_duplicates(subset='ID', inplace = True)
    
    # Ratings Plots
    print('Plots for Ratings Data')
    
    # Shown as binned ratings
    bins = [0,1,2,3,4,5]
    pd.cut(dat['Average User Rating'], bins).value_counts().plot(kind = 'bar')
    plt.xlabel('Scores')
    plt.ylabel('Count')
    plt.title('Scores Histogram')
    plt.show()
    
    #Show all ratings
    plt.hist(dat['Average User Rating'].dropna())
    plt.xlabel('Scores')
    plt.ylabel('Count')
    plt.title('Scores Histogram')
    plt.show()
    
    print('Number of Reviews')
    
    plt.hist(dat['User Rating Count'].dropna())
    plt.show()
    
    print('There is a long-tail to the data, so a subset will be shown as well')
    print('~80% of the data is pictured below')
    plt.hist(dat[dat['User Rating Count'] < 500].dropna(subset = ['User Rating Count'])['User Rating Count'])
    plt.show()

# %%
def visualize_raw_dat_cost():
    dat = pd.read_csv('../data/appstore_games.csv')
    dat.drop_duplicates(subset='ID', inplace = True)
    
    print('Cost of Games')
    
    plt.hist(dat['Price'].dropna())
    plt.xlabel('Price')
    plt.ylabel('Count')
    plt.title('Price Histogram')
    plt.show()
    
    print('Previous graph also has a long-tail. Will narrow the scope again')
    print('~99% of results in following graph')
    
    plt.hist(dat[(dat['Price'] < 15)]['Price'].dropna())
    plt.xlabel('Price')
    plt.ylabel('Count')
    plt.title('Price of Apps')
    plt.show()
    
    print('''84% of apps are free, skewing the results further. 
    Looking into only non-free apps for a clearer picture on what remains''')
    
    plt.hist(dat[(dat['Price'] < 15) & (dat['Price'] != 0)]['Price'].dropna())
    plt.xlabel('Price')
    plt.ylabel('Count')
    plt.title('Price of non-free Apps')
    plt.show()

# %%
visualize_raw_dat_ratings()
# Out:
# Plots for Ratings Data
# Number of Reviews
# There is a long-tail to the data, so a subset will be shown as well
# ~80% of the data is pictured below

# %%
visualize_raw_dat_cost()
# Out:
# Cost of Games
# Previous graph also has a long-tail. Will narrow the scope again
# ~99% of results in following graph
# 84% of apps are free, skewing the results further.
#     Looking into only non-free apps for a clearer picture on what remains

# %% [markdown]
# ## Truly Free vs cost and see what we find

# %% [markdown]
# In app purchases being nan => 0

# %%
dat['In-app Purchases'].fillna('0', inplace = True)

# %%
dat['true_free'] = (dat.Price == 0) & (dat['In-app Purchases'] == '0')

# %%
dat[dat.true_free == True].shape
# Out:
# (7062, 23)

# %%
dat[dat.true_free != True].shape
# Out:
# (9785, 23)

# %%
plt.hist(dat[dat.true_free == False]['Average User Rating'].dropna().values, label='Paid')
plt.hist(dat[dat.true_free == True]['Average User Rating'].dropna().values, label='Free')

plt.legend(loc='upper right')
plt.show()

# %%
plt.hist(dat[dat.true_free == True]['Average User Rating'].dropna().values, label='Free')
plt.hist(dat[(dat.true_free == False) & (dat.Price != 0)]['Average User Rating'].dropna().values, label='Paid')

plt.legend(loc='upper right')
plt.show()

# %%
plt.hist(dat[dat.true_free == False]['Size'].dropna().values, label='Paid')
plt.hist(dat[dat.true_free == True]['Size'].dropna().values, label='Free')

plt.legend(loc='upper right')
plt.show()

# %%
def autolabel(rects, counts):
    """
    Attach a text label above each bar displaying its height
    """

    '''
    Got this from 
    https://stackoverflow.com/questions/30228069/how-to-display-the-value-of-the-bar-on-each-bar-with-pyplot-barh

    Altered it to but whatever text I wanted on the bar instead of the height
    '''
    for x, rect in zip(counts, rects1):
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., height,
                'n = ' + str(x),
                ha='center', va='bottom')

def prep_visualize_cost():
    dat = pd.read_csv('../data/appstore_games.csv')
    dat.drop_duplicates(subset='ID', inplace = True)
    
    # Assume if null then there are no in-app purchases since all others have a value
    dat['In-app Purchases'].fillna('0', inplace = True)
    
    # An app is only actually free if you cant buy anything once in it
    dat['true_free'] = (dat.Price == 0) & (dat['In-app Purchases'] == '0')
    
    # Look at only if there is a base cost first and see if rating difference exists
    
    print('Investigate differences in ratings by free vs. paid App')
    plt.hist(dat[dat.true_free == True]['Average User Rating'].dropna().values, label='Free', color = 'green')
    plt.hist(dat[(dat.true_free == False) & (dat.Price != 0)]['Average User Rating'].dropna().values, label='Paid')

    plt.legend(loc='upper right')
    plt.show()
    
    print('Many Apps included pain content within them. These should not truly be considered "free"')
    
    plt.hist(dat[dat.true_free == False]['Average User Rating'].dropna().values, label='Paid')
    plt.hist(dat[dat.true_free == True]['Average User Rating'].dropna().values, label='Free', color = 'green')

    plt.legend(loc='upper right')
    plt.show()
    
    print('Which are truly best?')
    
    non_true_free_rating = dat[dat.true_free == False]['Average User Rating'].dropna().mean()
    in_app_purchases = dat[(dat.true_free == False) & (dat.Price == 0)]['Average User Rating'].dropna().mean()
    true_free_rating = dat[dat.true_free == True]['Average User Rating'].dropna().mean()
    zero_cost_rating = dat[dat.Price == 0]['Average User Rating'].dropna().mean()
    paid_rating = dat[dat.Price != 0]['Average User Rating'].dropna().mean()

    non_true_free_rating_cnt = dat[dat.true_free == False]['Average User Rating'].dropna().shape[0]
    in_app_purchases_cnt = dat[(dat.true_free == False) & (dat.Price == 0)]['Average User Rating'].dropna().shape[0]
    true_free_rating_cnt = dat[dat.true_free == True]['Average User Rating'].dropna().shape[0]
    zero_cost_rating_cnt = dat[dat.Price == 0]['Average User Rating'].dropna().shape[0]
    paid_rating_cnt = dat[dat.Price != 0]['Average User Rating'].dropna().shape[0]

    plt.bar(['Zero Cost','Paid App'],
            [zero_cost_rating,paid_rating])
    plt.ylim((3.8,4.18))
    plt.xticks(rotation = 'vertical')
    plt.show()
    
    plt.bar(['Truly Free','Any Cost'],
            [true_free_rating,non_true_free_rating])
    plt.ylim((3.8,4.18))
    plt.xticks(rotation = 'vertical')
    plt.show()
    
    plt.bar(['Zero Cost','Truly Free','Paid App','Any Cost','In app-purchases'],
            [zero_cost_rating,true_free_rating,paid_rating,non_true_free_rating, in_app_purchases])
    plt.ylim((3.8,4.18))
    plt.xticks(rotation = 'vertical')
    plt.show()
    
    N = 5

    ind = np.arange(N)  # the x locations for the groups
    width = 0.35       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind, [zero_cost_rating,true_free_rating,paid_rating,non_true_free_rating, in_app_purchases], 
                    width, color='r')


    # add some text for labels, title and axes ticks
    ax.set_ylabel('Scores')
    ax.set_title('Scores by group and gender')
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels(['Zero Cost','Truly Free','Paid App','Any Cost','In app-purchases'])

    plt.ylim((3.85,4.18))

    counts = [zero_cost_rating_cnt,true_free_rating_cnt,paid_rating_cnt,non_true_free_rating_cnt, in_app_purchases_cnt]


    autolabel(rects1, counts)

    plt.show()

# %%
prep_visualize_cost()
# Out:
# Investigate differences in ratings by free vs. paid App
# Many Apps included pain content within them. These should not truly be considered "free"
# Which are truly best?

# %% [markdown]
# Overwhelmingly games so look at the others only

# %%
plt.bar(dat[dat.true_free == False]['Primary Genre'].value_counts().index[1:], 
        dat[dat.true_free == False]['Primary Genre'].value_counts().values[1:])
plt.show()

# %% [markdown]
# Time since last release at time data was pulled -> indicator of how active it is

# %% [markdown]
# Data stored as dd-mm-yyyy

# %%
dat['curr_release_date'] = pd.to_datetime(dat['Current Version Release Date'], format="%d/%m/%Y")

# %%
dat['time_since_update'] = (np.datetime64('2019-08-03') - dat['curr_release_date']).astype('timedelta64[D]')

# %% [markdown]
# Some are now negative since apparently they were released after the crawl? Going back to just using time since today's date

# %%
dat['time_since_update'] = (np.datetime64('today') - dat['curr_release_date']).astype('timedelta64[D]')

# %%
# Look at how many days since updates for apps
dat.time_since_update.hist()
plt.show()

# %%
dat['time_since_update_bin'] = pd.cut(dat.time_since_update, bins=10, labels=[i for i in range(10)])

# %%
dat.groupby('time_since_update_bin')['Average User Rating'].mean().plot(kind = 'bar')
plt.show()

# %%
def time_since_update_stats(num_bins = 10):
    '''
    Previous steps needed to make this work:
    
    dat['curr_release_date'] = pd.to_datetime(dat['Current Version Release Date'], format="%d/%m/%Y")
    dat['time_since_update'] = (np.datetime64('today') - dat['curr_release_date']).astype('timedelta64[D]')
    
    '''
    
    print('Loading previously parsed file from ../data/parsed_data.parquet')
    
    dat = pd.read_parquet('../data/parsed_data.parquet')
    
    dat.time_since_update.hist()
    plt.show()
    
    print('Segmenting data with ' + str(num_bins) + ' bins')
    dat['time_since_update_bin'] = pd.cut(dat.time_since_update, bins=num_bins, labels=[i for i in range(num_bins)])
    
    dat.groupby('time_since_update_bin')['Average User Rating'].mean().plot(kind = 'bar')
    plt.show()

# %%
time_since_update_stats(20)
# Out:
# Loading previously parsed file from ../data/parsed_data.parquet
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:707: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels = getattr(columns, 'labels', None) or [
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:734: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return pd.MultiIndex(levels=new_levels, labels=labels, names=columns.names)
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:751: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels
# Segmenting data with 20 bins

# %% [markdown]
# See if URL or images are still active now

# %%
images = []
for i in dat['Icon URL'].values:
    try:
        response = requests.get(i)
        images.append(response.content)
    except Exception as e:
        images.append(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-8f44bdfb9d6b> in <module>()
#       2 for i in dat['Icon URL'].values:
#       3     try:
# ----> 4         response = requests.get(i)
#       5         images.append(response.content)
#       6     except Exception as e:
#
# /anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /anaconda/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /anaconda/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %%
len(images)
# Out:
# 16733

# %%
def get_image_bytes(df, col):
    '''
    Parameters: 
    df (df): dataframe with urls in it
    col (str): column which contains the urls

    Returns: 
    list: list of the contents returned from the url
    
    This take a VERY long time to run. Try to minimize number of times this needs to run
    '''
    images = []
    for i in df[col].values:
        try:
            response = requests.get(i)
            images.append(response.content)
        except Exception as e:
            images.append(None)
    return images

# %%
images_2 = []
for i in dat['Icon URL'].values[len(images):]:
    try:
        response = requests.get(i)
        images_2.append(response.content)
    except Exception as e:
        images_2.append(None)

# %%
images_3 = images + images_2

# %%
len(images_3)
# Out:
# 16847

# %%
dat['image_bytes'] = images_3

# %%
dat.to_parquet('../data/parsed_data.parquet')
# Out:
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:114: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   result = infer_dtype(pandas_collection)

# %%
def desc_cleanser(txt):
    # New line issues
    txt = re.sub(r'\\n', r' ', txt)
    # Unicode cleanse
    txt = re.sub(r'\\u[\d]{4}', r'', txt)
    # Remaining unicode cleanse
    txt = re.sub(r'\\{1,2}\S+', r' ', txt)
    # Remove remaining non-alphanumeric and spaces
    txt = ''.join([i for i in txt if i.isalnum() or i.isspace() or i in ['.','?','!']])
    # Remove more than a single space
    txt = re.sub(r'\s+', r' ', txt)

    return txt

# %%
dat['parsed_desc'] = dat.Description.apply(desc_cleanser)

# %%
dat.sort_values('time_since_update')
# Out:
#                                                                             URL  \
# 16980           https://apps.apple.com/us/app/block-soldier-sniper/id1474206079
# 16951   https://apps.apple.com/us/app/war-shooting-battle-survival/id1473098634
# 16942         https://apps.apple.com/us/app/flying-carpet-shooting/id1472974346
# 16902       https://apps.apple.com/us/app/island-jurassic-survival/id1471952843
# 16879  https://apps.apple.com/us/app/terrorist-shooter-city-missio/id1471495472
# ...                                                                         ...
# 11                         https://apps.apple.com/us/app/lumen-lite/id288096268
# 14                      https://apps.apple.com/us/app/tetravex-lite/id288918962
# 25                          https://apps.apple.com/us/app/gaia-lite/id292274288
# 10                          https://apps.apple.com/us/app/quaddraxx/id287563734
# 9                       https://apps.apple.com/us/app/barrels-o-fun/id286682679
#
#                ID                            Name                  Subtitle  \
# 16980  1474206079            Block Soldier Sniper              Block Sniper
# 16951  1473098634    War Shooting Battle Survival  Shooting Battle Survival
# 16942  1472974346          Flying Carpet Shooting           Carpet Shooting
# 16902  1471952843        Island Jurassic Survival             Dino Shooting
# 16879  1471495472  Terrorist Shooter: City Missio     City Shooting Mission
# ...           ...                             ...                       ...
# 11      288096268                      Lumen Lite                       NaN
# 14      288918962                   Tetravex Lite                       NaN
# 25      292274288                       Gaia Lite                       NaN
# 10      287563734                       Quaddraxx                       NaN
# 9       286682679                "Barrels O' Fun"                       NaN
#
#                                                                                                   Icon URL  \
# 16980  https://is5-ssl.mzstatic.com/image/thumb/Purple123/v4/05/85/af/0585af51-2fe3-9fa2-8e83-d9b6b20d0...
# 16951  https://is5-ssl.mzstatic.com/image/thumb/Purple123/v4/f2/50/7f/f2507f68-5bdc-d187-df27-958ad4fcd...
# 16942  https://is2-ssl.mzstatic.com/image/thumb/Purple113/v4/dc/37/7b/dc377b51-a369-ed84-724a-7bacdc303...
# 16902  https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/be/f9/27/bef92797-e0b4-3ebb-0efe-d6ebb903a...
# 16879  https://is1-ssl.mzstatic.com/image/thumb/Purple113/v4/41/b7/35/41b73511-3548-a381-bc00-639b4a573...
# ...                                                                                                    ...
# 11     https://is1-ssl.mzstatic.com/image/thumb/Purple71/v4/b9/ab/5a/b9ab5a52-aea9-fc5c-02f6-2e892192d3...
# 14     https://is3-ssl.mzstatic.com/image/thumb/Purple/v4/94/b3/96/94b396bd-f59e-7d1f-52cb-f0b388939c0e...
# 25     https://is1-ssl.mzstatic.com/image/thumb/Purple/v4/5c/7c/d5/5c7cd5b4-0b74-4360-bbe6-8a2667507020...
# 10     https://is5-ssl.mzstatic.com/image/thumb/Purple/v4/df/b6/1d/dfb61daf-4eb6-30ad-835a-d68346d0e817...
# 9      https://is4-ssl.mzstatic.com/image/thumb/Purple/v4/4a/b8/cd/4ab8cd35-6025-ccba-bb8b-44882dda46c2...
#
#        Average User Rating  User Rating Count  Price In-app Purchases  \
# 16980                  NaN                NaN    NaN       2.99, 9.99
# 16951                  NaN                NaN    NaN                0
# 16942                  NaN                NaN    NaN                0
# 16902                  NaN                NaN    NaN                0
# 16879                  NaN                NaN    NaN                0
# ...                    ...                ...    ...              ...
# 11                     3.5             5072.0    0.0                0
# 14                     2.5             2358.0    0.0                0
# 25                     3.5             1563.0    0.0                0
# 10                     NaN                NaN    0.0                0
# 9                      2.5              184.0    0.0                0
#
#                                                                                                Description  \
# 16980  This is block wars the game. This sniper games is very funny\n\nFeatures of Game:\n- Easy and fu...
# 16951  Play as a last world war hero to recapture army base in War Shooting Battle Survival. In this fi...
# 16942  Fly through the skies with your magic carpet and shoot enermy\n\nGame Features:\n-Beautiful grap...
# 16902  Island Jurassic Survival is a real thrill and fun game of enjoyment if you are a real hunter the...
# 16879  As a swat force agent and get ready to take down killers, terrorist and international criminals ...
# ...                                                                                                    ...
# 11     "The objective of Lumen is to light up all the checkpoints in the puzzle by bouncing, coloring, ...
# 14     Play the classic edge matching puzzle game Tetravex on your iPhone or iPod Touch!  Arrange the t...
# 25     Maximize your score for the first four levels of our top rated puzzle game in this free version....
# 10     Quaddraxx-Logic \u2013 Challenge your brain!\n\nDissolve a 3D cube made up of dice by rotating o...
# 9      Barrels O\u2019 Fun is a simple but challenging solitaire game where you match barrels to clear ...
#
#                           Developer Age Rating Languages         Size  \
# 16980                   VU HUU VIET        17+        EN  170358784.0
# 16951               VONG KIM PHUONG        17+        EN  261016576.0
# 16942              NGUYEN VAN QUANG        17+        EN  101702656.0
# 16902             NGUYEN THANG LONG        17+        EN  306213888.0
# 16879               VONG KIM PHUONG        17+        EN  222621696.0
# ...                             ...        ...       ...          ...
# 11                  Bridger Maxwell         4+        EN    7086403.0
# 14                 Futrell Software         4+        EN     731525.0
# 25            Quicksand Interactive         4+        EN    6550985.0
# 10     H2F Informationssysteme GmbH         4+        EN    3089867.0
# 9                          BesqWare         4+        EN    1466515.0
#
#       Primary Genre                                  Genres  \
# 16980         Games  Games, Strategy, Casual, Entertainment
# 16951         Games  Games, Entertainment, Casual, Strategy
# 16942         Games   Games, Strategy, Entertainment, Music
# 16902         Games  Games, Entertainment, Strategy, Action
# 16879         Games  Games, Strategy, Entertainment, Action
# ...             ...                                     ...
# 11            Games                 Games, Puzzle, Strategy
# 14            Games  Games, Puzzle, Strategy, Entertainment
# 25            Games                 Games, Strategy, Puzzle
# 10            Games  Games, Entertainment, Strategy, Puzzle
# 9             Games                 Games, Casual, Strategy
#
#       Original Release Date Current Version Release Date  true_free  \
# 16980            26/10/2019                   26/10/2019      False
# 16951            14/10/2019                   14/10/2019      False
# 16942            13/10/2019                   13/10/2019      False
# 16902             9/10/2019                    9/10/2019      False
# 16879             3/10/2019                    3/10/2019      False
# ...                     ...                          ...        ...
# 11               18/08/2008                   22/11/2008       True
# 14               27/08/2008                   21/10/2008       True
# 25                2/10/2008                    2/10/2008       True
# 10               11/08/2008                   30/09/2008       True
# 9                 1/08/2008                    1/08/2008       True
#
#       curr_release_date  time_since_update  \
# 16980        2019-10-26              -84.0
# 16951        2019-10-14              -72.0
# 16942        2019-10-13              -71.0
# 16902        2019-10-09              -67.0
# 16879        2019-10-03              -61.0
# ...                 ...                ...
# 11           2008-11-22             3906.0
# 14           2008-10-21             3938.0
# 25           2008-10-02             3957.0
# 10           2008-09-30             3959.0
# 9            2008-08-01             4019.0
#
#                                                                                                image_bytes  \
# 16980  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 16951  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 16942  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 16902  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 16879  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# ...                                                                                                    ...
# 11     b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x06\x04\x05\x0...
# 14     b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 25     b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 10     b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 9      b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
#
#                                                                                                parsed_desc
# 16980  This is block wars the game. This sniper games is very funny Features of Game: - Easy and fun to...
# 16951  Play as a last world war hero to recapture army base in War Shooting Battle Survival. In this fi...
# 16942  Fly through the skies with your magic carpet and shoot enermy Game Features: -Beautiful graphics...
# 16902  Island Jurassic Survival is a real thrill and fun game of enjoyment if you are a real hunter the...
# 16879  As a swat force agent and get ready to take down killers, terrorist and international criminals ...
# ...                                                                                                    ...
# 11     "The objective of Lumen is to light up all the checkpoints in the puzzle by bouncing, coloring, ...
# 14     Play the classic edge matching puzzle game Tetravex on your iPhone or iPod Touch! Arrange the ti...
# 25     Maximize your score for the first four levels of our top rated puzzle game in this free version....
# 10     Quaddraxx-Logic Challenge your brain! Dissolve a 3D cube made up of dice by rotating or switchin...
# 9      Barrels O Fun is a simple but challenging solitaire game where you match barrels to clear the bo...
#
# [16847 rows x 23 columns]

# %%
dat.to_parquet('../data/parsed_data.parquet')
# Out:
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:114: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   result = infer_dtype(pandas_collection)

# %%
dat = pd.read_parquet('../data/parsed_data.parquet')
# Out:
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:707: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels = getattr(columns, 'labels', None) or [
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:734: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return pd.MultiIndex(levels=new_levels, labels=labels, names=columns.names)
# /anaconda/lib/python3.6/site-packages/pyarrow/pandas_compat.py:751: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels

# %% [markdown]
# ## Will drop nulls across the board for image computation as they are very time-intensive

# %%
first = Image.open(BytesIO(images_3[0]))
second = Image.open(BytesIO(images_3[1]))

# %%
def dif_percentage(first,second):
    '''
    Pixel-wise differences between images
    '''
    i1 = first
    i2 = second
    assert i1.mode == i2.mode, "Different kinds of images."
    assert i1.size == i2.size, "Different sizes."

    pairs = zip(i1.getdata(), i2.getdata())
    
    #Manhatten distance for images
    
    if len(i1.getbands()) == 1:
        # for gray-scale jpegs
        dif = sum(abs(p1-p2) for p1,p2 in pairs)
    else:
        dif = sum(abs(c1-c2) for p1,p2 in pairs for c1,c2 in zip(p1,p2))

    ncomponents = i1.size[0] * i1.size[1] * 3
    return (dif / 255.0 * 100) / ncomponents

# %%
def dif_percentage_lst(first,lst):
    '''
    Pixel-wise differences between images
    Narrow the scope for images by resizing to be smaller for faster computations
    '''
    
    i1 = Image.open(BytesIO(first)).resize((50,50))
    hold = []
    for idx,i2 in enumerate(lst):
        i2 = Image.open(BytesIO(i2)).resize((50,50))
        if i1.mode != i2.mode:
            hold.append(100)
            continue
        assert i1.size == i2.size, "Different sizes."
        
        pairs = zip(i1.getdata(), i2.getdata())

        #Manhatten distance for images

        if len(i1.getbands()) == 1:
            # for gray-scale jpegs
            dif = sum(abs(p1-p2) for p1,p2 in pairs)
        else:
            dif = sum(abs(c1-c2) for p1,p2 in pairs for c1,c2 in zip(p1,p2))

        ncomponents = i1.size[0] * i1.size[1] * 3
                
        hold.append((dif / 255.0 * 100) / ncomponents)
    return hold

# %%
first = Image.open(BytesIO(dat.image_bytes[1]))
second = Image.open(BytesIO(dat.image_bytes[2]))
rands = Image.open(BytesIO(dat.image_bytes[50]))

# %%
dif_percentage(first, second)
# Out:
# 18.08202506669986

# %% [markdown]
# Test for similarities of a single image

# %%
res = dif_percentage_lst(dat.dropna().image_bytes.values[0], dat.dropna().image_bytes.values)

# %%
def gather_names(df,lst,col):
    lst_return = []
    for i in lst:
        lst_return.append(df.iloc[i][col])
    return lst_return

# %%
gather_names(dat.dropna(),list(pd.Series(res).sort_values().index),'Name')
# Out:
# ['Sudoku - Classic number puzzle',
#  'Speedy Square!',
#  'Kakuro Game',
#  '2048+#',
#  'Black Blue',
#  'CityScape Sim',
#  'NRTM',
#  'Biocell',
#  'Swim Out',
#  'TicTacToe - Multiplayer Game',
#  'Steampunk Puzzle Physics Game',
#  'Slam Sky',
#  'Conference Room Escape',
#  'Kubos.',
#  'Opp Ball',
#  'Universal Papertoilet Clicker',
#  'Net Deck',
#  'Sudoku \\u229e',
#  'FLASHFLUSH',
#  'Guess Her Age',
#  'Foodie Finds',
#  'Tetra Cats',
#  'Achi - Strategy game',
#  'Sudoku+ Classic Puzzle',
#  'Wall Ball - Bounce',
#  'South Park: Phone Destroyer\\u2122',
#  'Fortune City - Expense Tracker',
#  'Pixel Plex',
#  'Infection Go',
#  'Domino! - Multiplayer Dominoes',
#  'Idiot Test - Brain Teasers and Mind Games',
#  'Magic Life Counter',
#  '[Minesweeper]',
#  'Sudoku - soduku puzzles',
#  'Dual Match 3',
#  'Sixteen The Puzzle',
#  'SEA BATTLE ONLINE 2',
#  'Laws of Civilization LITE',
#  'Mahjong Catalog',
#  'Idle Water Slide',
#  'Card Creator for MtG',
#  'Idle Donut Tycoon',
#  'Laws of Civilization',
#  'NightZero:Mistiltein',
#  '"Crap! I\'m Broke: Out of Pocket"',
#  'CodeWords - Name Clue Game',
#  'Cut The Ice Blocks With Three Slices',
#  'Cut Ice Blocks With Three Slices Pro',
#  'Landix.io Split Snake Cells',
#  'Shtcoin',
#  'IQ Test: Calculate your IQ',
#  'Triangle - Strategy Game',
#  'City Island 3: Building Sim',
#  'Tic Tac toe puzzle game',
#  'Summit Way',
#  'Egg, Inc.',
#  'Slayaway Camp',
#  'Pig Hunter - Tien Len/Thirteen',
#  'Ball Slide',
#  'ChaosMasters',
#  'Piece Out',
#  'Osomatsu-san Hesokuri Wars',
#  'You Call The Play',
#  'Mr Go Home',
#  'Cats Tower - Merge Kittens!',
#  'Chess 2 player - Chess Puzzle',
#  'Infection of the dead',
#  'Hit Block-stroke one line draw',
#  'Pica Pica!',
#  'Pastry Jam Sega',
#  'Record Egg Idle Game',
#  '* Tournaments for Clash Royale',
#  'Zipline Valley',
#  'Chess Duel',
#  'Scythe score',
#  'Woody Crazy ten ten slices',
#  'Snake Candy.IO',
#  '9 Moves-Ball game for everyone',
#  'ChartHopper',
#  'Idle Harbor Tycoon - Sea Docks',
#  'Ludo 3D : Aeroplane Chess',
#  'Smash Car Clicker 2',
#  'Tic-Tac-Toe\\xb2',
#  'Doodle God: Merge Evolution',
#  '2048 Logic puzzle Game',
#  'Spider Solitaire X!',
#  'Twelvesmith',
#  '2048\\uff0e',
#  'Catan Map Generator Chat Bot',
#  'Math Matches',
#  'Cardstock - for MtG',
#  'Catomic Match 3: Cats in Space',
#  'City Island 2: Building Story',
#  '2048 Classic \\xb7 Swipe Game',
#  'Color Block Puzzle - Match 3',
#  'Fish Farm - Idle game',
#  'Merge Food',
#  'Defend the Cake Tower Defense',
#  'Steel Generals WWII Online RTS',
#  'Biters.io',
#  'Stack Yea!',
#  'Dominoes: Classic Dominos Game',
#  'Patternade',
#  'Sheeping Around',
#  'Spinner Evolution - Merge It!',
#  'Cribbage Square - Solitaire',
#  'Bloon Popper - pop',
#  'Fisherman - Idle Fishing Game',
#  'UTH - United Treasure Hunt',
#  'Worry_Bead',
#  'CITY REAL ESTATE TYCOON',
#  'Impossible Speed Reading Game',
#  'Sheepshop Idle Fashion Tycoon',
#  'Craft Warriors',
#  'Idle Gun Tycoon',
#  'Bl1NK',
#  'Sudoku Puzzles',
#  'FreeCell by Pokami',
#  'Chess \\u25e7',
#  'LogJump',
#  'Bot Land',
#  'Turn White',
#  'Car Wash Empire',
#  'Mahjong Challenge Tile Matches',
#  'Tic-Tac-Two',
#  'Infinite West - Puzzle Chess',
#  'Stormy Cat',
#  'Conceptis SumSudoku',
#  'Lead Wars',
#  'Rupie: city clicker hero',
#  'SimCity BuildIt',
#  'Fighter 3D - Air combat game',
#  'Agar.io',
#  'Crossy Chick Running',
#  'Kakuro++ Cross Sums',
#  'Merge Plants',
#  'Hexavoid',
#  'Conceptis Tic-Tac-Logic',
#  'Tic Tac Toe OXO',
#  'Valley I',
#  'Working Cats',
#  'Office Story',
#  'Divine Academy: Town Building',
#  'TotalMatch',
#  'Minesweeper\\u2218',
#  'Cell Strike - all access',
#  'Gotchuu - Local Food Fights',
#  'Circle Two',
#  'Navy Base',
#  'Bud Farm: Grass Roots',
#  '"Eric\'s Sudoku \\u2013Classic Puzzles"',
#  'Neo Monsters',
#  'Evolution Board Game',
#  'Balance IT',
#  'Zgirls',
#  'Port Control',
#  'Color Crush \\xb7 Matching Game',
#  'Sixteen Soldiers : Bead 16',
#  'Ball Breaker - Flappy Bounce',
#  'Conceptis Hashi',
#  'Merge Desserts - Idle Game',
#  'Everest Attack - Mountain Climbing',
#  'Jurassic World Alive',
#  'Eight-Minute Empire',
#  'MPG Football',
#  'Dangerous Basement Rush',
#  'Pivotol',
#  'Asterix and Friends',
#  'Langrisser',
#  'Flicky Chicky',
#  'Police Inc: Tycoon sim game',
#  'Heroes Clash - Zombies War',
#  'Marble Idle 3D',
#  'Match Maker: The Video Game',
#  'Shnarps - Classic Card Game',
#  'Sudoku Mega Bundle',
#  'Sudoku\\xb7\\xb7',
#  'Concrete Jungle',
#  'Viking Village Premium',
#  'Viking Village',
#  'Farm Pop : Farm Pet story',
#  'Fiz: Brewery Management Game',
#  'ScoreFive',
#  'Color Hit: destroy the blocks',
#  'Idle Towers',
#  'Bubble Shooter Game Classic',
#  'Project Highrise',
#  'Conceptis Sudoku',
#  'Avoid The Squares!',
#  'Capture',
#  'Spinners!',
#  'Flip it up~!',
#  'Oil Tycoon 2 -Gold Clicker Inc',
#  '3DTD: Chicka Invasion',
#  'Shoot.io ONLINE Battle Ship',
#  'Last Arrows',
#  'Brofist Legend',
#  'World Dominator',
#  'Desktop Tower Defense!',
#  'Tall Chess',
#  'Wild Chase : Crowd Battle',
#  'Empire Manager (Civ Manager)',
#  'Conceptis MultiSudoku',
#  'Match Fives',
#  'Smash Tournament',
#  'Crazy Chess Random - BA.net',
#  '2048 Guns',
#  'Letter Boxes',
#  'Star Girl Christmas',
#  'Idle Roller Coaster',
#  'Airport Terminal 2',
#  'Sliding Puzzle - Board Game',
#  'Bow and Arrow Archery Shooting Target Game',
#  'Backgammon Unlimited',
#  'Airport City',
#  'Idle Island - City Builder',
#  'Mutility Life Counter for MTG',
#  'Clone Sheep - Jump and Run',
#  'Yacht - Classic with variants',
#  'Capitalist-Taps to riches',
#  'Merge Unicorn - Idle Evolution',
#  'Chess Star - Play Online',
#  'Octav',
#  'Hammurabi, The Game',
#  'Virtual Pet Corny and Farm.',
#  'Megapolis: Building Strategy',
#  'Star Girl: Beauty Queen',
#  'MagicPenA',
#  'Power Painter: Shoot & Paint',
#  'Math Genius - Multiplayer',
#  'Idle Defence',
#  'Idle Factory Tycoon',
#  'Create Dozens',
#  'Medieval Skirmishes',
#  'Cookie Cats\\u2122',
#  'Gear Factory: Incremental Game',
#  'Bankrupt - Best Business Game',
#  'Baduk Cap',
#  'Rabbit Evolution Merge in Farm',
#  'Toy Defense Fantasy \\u2014 TD Tower',
#  'CivCrafter',
#  'Cooking Hot Cooking Games',
#  'Smartphone Tycoon 2',
#  'RollerCoaster Tycoon\\xae 4Mobile\\u2122',
#  'HIARCS Chess',
#  'City Island 4 Simulation Town',
#  'Bear Pop - Bubble Shooter Game',
#  'Pocket City',
#  'Hero Defense King : TD',
#  'Fantasy Legend:War of Contract',
#  'Marimo League',
#  'Candy Jewel Easter Match 3',
#  'Easter Eggs Mahjong Towers',
#  'Helix Color Ball Jump 3d 2019',
#  'F1 Manager',
#  'Klaverjassen Lite',
#  'Pirates Outlaws',
#  'NBTD Solitaire Lite',
#  'LINED!',
#  'Desktop Tower Defense Pro!',
#  'Chinese Chess - Best XiangQi',
#  'City Building Games GO',
#  'Klaverjassen',
#  'My Cafe Story3 -DONBURI SHOP-',
#  'Conceptis SeaBattle',
#  'Rooter  - Live Sports App',
#  'Industrialist - My factory',
#  'Forgestone',
#  'Roller Splat-AMAZE Paint',
#  'PopKarts Food Fighters Defense',
#  'Mini Metro',
#  'War Clash',
#  'Puralax',
#  'Airport-Control',
#  'Bubble Shooting Classic Games',
#  'Zoo Park Idle',
#  'Milk Factory',
#  'Cubees',
#  'Carrier Battles 4 Guadalcanal',
#  'Survey Party',
#  'Minesweeper!',
#  'Co Tuong Viet Nam - Co Vuong',
#  'Hello Kitty Jewel Town!',
#  'Towar.io - Online Battles',
#  'Idle Waterpark 3D Fun Aquapark',
#  'SubSweep',
#  'Escape The Classroom',
#  'HIARCS Chess for iPad',
#  'Formula Clicker Idle Tycoon',
#  'World War 1914',
#  'Army Commander Simulator',
#  'Hive 5',
#  'Global Supremacy',
#  '"No Man\'s Hotel:Room Escape"',
#  'Restaurant Tycoon',
#  'Euchre Mobile',
#  'Chess Score Pad',
#  'Silent House',
#  'Aircraft Oops - Build Airport',
#  'Cookies! Sweet Clicker Game',
#  'Idle Tower',
#  'Minesweeper XL classic + undo',
#  'Mage | Market for Magic (MTG)',
#  'Kuros Classic',
#  'Motu Pop - Bubble Shooter Game',
#  'Castle Defender - Idle War',
#  'BATPLA - Battle for the Planet',
#  'Connect 5',
#  'Idle Tower Tycoon',
#  'Picnic Auto Chess Strategy PvP',
#  'Pocket Tower\\uff0dSkyscraper Tycoon',
#  'Backgammon Ultimate',
#  'Wargame: France 1940',
#  'Meow Wars',
#  'OUTNUMBERED - A Puzzle Game to connect Numbers',
#  'ExpressRoad',
#  'Cricket Captain 2018',
#  'Empire Warriors: Tower Defense',
#  'Solitaire Game Collection',
#  'Solitaire Collections',
#  'Math Hero by Erudite',
#  'Megapolis HD: city tycoon sim',
#  'Pixnuri -Minesweeper,Griddlers',
#  'Call Baby',
#  'AquaLife 3D',
#  'Border War: Frontline Fury Att',
#  'EasyGo Pro',
#  'Tower Builder : Top Fun Game',
#  'Chess Online +',
#  'Idle Knights',
#  'Virtual Pet Dino and Farm.',
#  'Elvenar - Fantasy Kingdom',
#  'Keto Krash - Keto Match Game',
#  'Final Battleground Shooting',
#  'Wicked Snow White',
#  'Le Havre (The Harbor)',
#  'Mahjong Blitz',
#  'Gravity Orange 2',
#  'Drunk Hibachi: Crazy Cooking',
#  'Penalty Decider',
#  'Be A Man: Do The Right Thing',
#  '10-in-1 Board Games BA.net',
#  'Fighter 3D Lite - Air Combat',
#  'Cheesar',
#  'Poop The Potato -Shooting Game',
#  'Magic Brick Wars',
#  'Gaydorado',
#  'I.Q. - Test',
#  'Impeached: Be The President',
#  'World Wide Resort HD',
#  'Towering Tiles',
#  'Naval Storm TD',
#  'World Wide Resort',
#  'TI3 Race Sheet',
#  'Idle Painter',
#  'Crush the Castle',
#  'Simple Switch',
#  'Oil Tycoon: Tap City Miner Inc',
#  'NBTD FreeCell Lite',
#  'Idle Movings',
#  'ChickenDinner SportsBook',
#  'Cruel Solitaire - Classic',
#  'Simply Knights',
#  'Empire Penguin - Money Tycoon',
#  'Gunship Battle Total Warfare',
#  'Hidden Object Spring Gardens & Spy Easter Objects',
#  '"Simon\'s Cat - Pop Time"',
#  'Saving the dead world',
#  'World War 2 - Online Strategy',
#  'Wargame: Sicily 1943',
#  'Epic Party Clicker',
#  'City Driving - Traffic Puzzle',
#  '"Chomp\'d - Survival Game"',
#  'FishCure:stay focused',
#  '"Papa\'s Scooperia HD"',
#  'Checkmate!',
#  'Teachley: Addimal Adventure',
#  'Santorini Board Game',
#  'Merge Taxi 3D',
#  'Lost In Holland',
#  'Fun Bridge',
#  'Skyscraper 4D',
#  'Food Cats',
#  'Aim Master',
#  'Island Tycoon!',
#  'Recruit: Tank Madness',
#  'CranialCrash: Corridor',
#  'Trade Tycoon Billionaire',
#  'Chess-Studio',
#  'Mayor Inc.',
#  'Idle City Manager',
#  '"Jean\'s Club"',
#  'My Pizza Shop 2',
#  'Idle Racing Tycoon',
#  'Ludo Game : 2019 King Star',
#  'BigCompany: Skytopia',
#  '"Freakin\' Flyin\' Duck"',
#  'Candy Chefs: Match 3',
#  'Difly.io',
#  'SD TankWar',
#  '#1 Fortnite Weekly Quick Quiz',
#  'RUDE  Gay Charades',
#  'SIEGE: World War II',
#  'Foodie Tower: Idle Shop Tycoon',
#  'Pop Culture Live',
#  'Iron Marines',
#  'Hex Isle Map',
#  'Solitaire by Pokami',
#  'VPET',
#  'Clicker: tap, stork, people',
#  'Hexium',
#  'Citytopia\\u2122',
#  'War of Bots - Metal Force War',
#  'Star Girl: Princess Gala',
#  'Mount Everest Story',
#  'Micro Golf Masters',
#  'Dotz.io Dots Battle Arena',
#  'LVL',
#  'WHAT ( bubbles )',
#  '"Cat\'n\'Robot: Idle Defense"',
#  'Diamond Rain - Catch the Falling Diamonds!',
#  'Clash of Mythos',
#  'Shapes Galore',
#  'Building Time!',
#  'Smashers.io Foes in Worms Land',
#  'Master Fantasy RPG Soundboard',
#  'Legendary Heroes offline MOBA',
#  'Times Tables x kids math games',
#  'King Rivals',
#  'Learn Chess with Dr. Wolf',
#  'Chess \\u2218',
#  'Snow Town - Ice Village World',
#  'Tap Tap Fish - AbyssRium',
#  'Escape From The Dinosaurs',
#  'Idle Supermarket Tycoon - Shop',
#  'Witch Puzzle - Match 3 Game',
#  'Crazy Cooking: Food Craze Game',
#  '"Jean\'s Boutique 2!"',
#  'TRADE ON - Social trading',
#  'Idle Theme Park - Tycoon Game',
#  'DayD: Through time',
#  'Amazing Wizards',
#  'Minesweeper For iPhone & iPad',
#  'Reversi Ultimate',
#  'Potion Punch',
#  'Clash Rider - Clicker Tycoon',
#  'Pocket Trader. Business Tycoon',
#  'Magic Alchemist Springtime Ed.',
#  'Mbrane',
#  'Cookie Cake Match',
#  'Designer City: Space Edition',
#  'Hidden Objects Desserts & Candy Cupcake Object Pic',
#  'Happy Cafe',
#  'NBTD Spider Lite',
#  'Shogi Demon',
#  'Shogi Demon XL',
#  'Idle Metro',
#  'Tap Forward',
#  'Mini Hospital',
#  'Words with Foxy',
#  'Idle Industry World',
#  'Dino Bash - Defend & Fight',
#  'Rescue Strike:Army Siege Comma',
#  'Battleship Classic Board Game',
#  'Let it Rainbow',
#  'Space Station Simulator',
#  'Alpha-Beta',
#  'Revolve8',
#  'Ancient buzzland',
#  '"John Allen\'s Timesaver Lite"',
#  '"John Allen\'s Timesaver Puzzle"',
#  'Possession of a Good Fortune',
#  'Conceptis Pic-a-Pix',
#  '"King\'s Bounty Legions: Tactics"',
#  'Stellar Age: MMO Strategy',
#  'My Ice Cream Shop',
#  '"Dragon\'s Watch RPG"',
#  'Pinochle Plus',
#  'Island Oasis Idle Tycoon',
#  'Alien Path',
#  'Defenders of the Realm !',
#  'WarOfBugs',
#  'Brainy Skills Inferencing Game',
#  'Farm, Inc.',
#  'Block Puzzle Jewel XI',
#  'Park of Monster',
#  'Kingdoms & Monsters',
#  'Bubble Buster Quest',
#  'Bots Boom Bang',
#  'Sdorica -mirage-',
#  'Happy Cat - Sky Fly By Balloon',
#  'Coin Billionaire AR',
#  'I am Giraffe',
#  'Nanuleu',
#  'Balloon Breaker',
#  'Mahjong Joy - Solitaire',
#  'Idle Colony Tycoon',
#  'Majesty: Fantasy Kingdom Sim',
#  'Ticket to Ride',
#  'Run An Empire',
#  'Crafty Town Idle City Builder',
#  'Tube Tycoon Simulator - Tapper',
#  'Chess Rush',
#  'WindWord',
#  'Heroes Of Expedition-NA',
#  'Sea Warriors',
#  'Marble Math Multiplication',
#  'Dolphin Evolution',
#  'Modern FPS: Combat Sniper 3D',
#  'Galaxy Run',
#  'EYE FACTORY - funny game',
#  'Mushroom Wars 2 \\u2013 Heroic RTS',
#  'Tank Merger - Idle Hero',
#  'Turtle Muck',
#  'Plunge Jo',
#  'Wild Battle Game 2019',
#  'Spider Solitaire by Pokami',
#  'Super Head Soccer Game',
#  'Bunny Pancake Milkshake Game',
#  'Merch Mania',
#  'Shadow Ninja Assassin Game',
#  'Hercules VII (Platinum)',
#  'Majesty: Northern Kingdom',
#  'American Trainworks',
#  '1010 Fit for  Blocks bricks',
#  'Infinity Dungeon 2',
#  'Whimsical War',
#  'Merge Bakery',
#  'Kingdom Wars Defense',
#  'Lords of Discord Fantasy TBS',
#  'Christmas Holiday Crush',
#  'Conceptis Slitherlink',
#  'Chess Online\\xb7',
#  'Chess Openings Wizard',
#  'Ambition of Kingdom',
#  'Candy Tycoon',
#  'Toy Defense 2 \\u2014 Tower Defense',
#  'Grow Empire: Rome',
#  'Brain points - Connect & loop',
#  'Food Diary: Cooking Games',
#  'Honeybee Garden',
#  'Magic Rush: Heroes',
#  'Dot.com Tycoon',
#  '"Sally\'s Spa HD"',
#  '"Papa\'s Pancakeria To Go!"',
#  'Majesty: Northern Expansion',
#  'Finabase: realtime stocks',
#  'Fortune Heroes: Coin Slot City',
#  'Business Tycoon 2',
#  'Rush (Rise up special heroes)',
#  'Steampumpkins: Catapult Action',
#  'Wedding Salon Dash',
#  'Pie in the Sky!',
#  'Onmyoji',
#  'Chess!!',
#  'APEX Wallpapers for Legends',
#  'Real Madrid Fantasy Manager 19',
#  'Merge Defense - Idle Boat',
#  'Bladers.io - Battle Tops',
#  'Crypto Idle Miner',
#  'So Social 2',
#  'Dice Hunter: Dicemancer Quest',
#  'Escape\\uff1aEndless Rooms',
#  'Hero Chess: Teamfight Auto',
#  'Epic Medieval Battle Simulator',
#  'Cutthroat Pinochle Gold',
#  'Crazy Kings',
#  '"Sid Meier\'s Civilization\\xae VI"',
#  'Scruples - The Game',
#  'Idle Zoo - Animal Park Tycoon',
#  'Holyday City Tycoon',
#  'Dune Wars!',
#  'HD Poker: Texas Holdem',
#  'Robots.io',
#  'Idle Car Empire',
#  '"Papa\'s Scooperia To Go!"',
#  'Stats & Tools for Clash Royale',
#  'Theme Park Clicker: Idle Hero',
#  'Blossom Flower Garden Match 3',
#  'Bitcoin Billionaire',
#  'Jewels & Gems - Match 3 Games',
#  'Plug It!',
#  'Marble Math Junior',
#  'Game of Earth: Build Your City',
#  'Rumble Heroes\\u2122',
#  'SmartGo Kifu',
#  'Jewel World Candy Deluxe',
#  'War Planet Online',
#  'Lie Dectector',
#  'Snix.io Snake Line Arena',
#  'Ancient Bowman',
#  'Exospecies',
#  'Hidden Objects - Florida Vacation Adventure Time',
#  'Solitaire Whizz',
#  'Space Endeavors',
#  'Hoppy Circle',
#  'First Class Flurry',
#  'Dots Out - A puzzle Adventure',
#  'Simply, Sudoku',
#  'Istanbul: Digital Edition',
#  'Forge of Empires: Build a City',
#  'Numbers.io',
#  'Gridular: A Number Puzzle Game',
#  'Idle Toll',
#  'Hidden Objects Candy Shop & Dessert Object Time',
#  'Ultimate Epic Battle Simulator',
#  'Pocket Zoo: Idle Keeper',
#  'Rise of Kingdoms',
#  '81 Tiles - Color Block Puzzle',
#  'Domino Score Sheet',
#  'Idle Medieval Tycoon - Clicker',
#  'Thunder Armada',
#  'Touchdown Manager',
#  'Brain Cracker Memory Game',
#  'Love Kpop Idol :Girl Group Inc',
#  'Jewel Castle - Matching Games',
#  'Number 100!',
#  'Warship Battle Simulator',
#  'Modern Ludo',
#  'Anna sleep slacking game',
#  '"Papa\'s Cupcakeria HD"',
#  'Spheroku Skillz',
#  'Tank Island 3D - Strategy game',
#  'Bubble Shooter Classic',
#  'Castle Wall Defense',
#  'Army Men Battle Simulator',
#  'Hell\\u2019s Cooking - madness fever',
#  'Creature Bounce',
#  'Solitaire',
#  'Cooking Madness',
#  'BuildInvest',
#  'Cake Smash',
#  'Space Colonizers Idle Clicker',
#  'United Legends',
#  'Airlines Manager : Tycoon 2019',
#  'Grassy Snake',
#  'Popcorn fill: A physics puzzle',
#  '\\u22c6Pyramid',
#  'Pyraminx Solver',
#  'Crazy Candy Lands',
#  'Bibble Burst',
#  'Decks Royale for Clash Royale',
#  'Parking Escape',
#  'Fun Snake Game - Cool Smash',
#  'Idle Jackpot: Catch the balls!',
#  'Hyper Flippy Cube',
#  'Defense Shadow Monsters',
#  'Toast Evolution - Idle Tycoon & Clicker Game',
#  'TowerMadness Zero',
#  'Soccer Royale Games 2019',
#  'SEGA Heroes: Puzzle RPG Quest',
#  'Virtual Stock Market Game',
#  'Blood & Honor: War and Risk',
#  'Battleship Empire',
#  'Sea Port: Ships & Trade Tycoon',
#  'Lords & Knights - X-Mas',
#  'Dead Island: Survivors',
#  'Valleys Between',
#  'Oil, Inc.- Idle Clicker Tycoon',
#  'Super Idle Cats - Farm Tycoon',
#  'Rebirth King',
#  'Ludo Championship',
#  'Fort Stars: Kingdom Battle',
#  '"Summoner\'s Greed: Idle RPG TD"',
#  'ATM Hacker',
#  'Civil Epic Battle 2-Fight For The City',
#  'Godus',
#  '1942 Pacific Front Premium',
#  'Dominoes Online Board Game',
#  '6th Grade Math: Fun Kids Games',
#  'Trak-it',
#  'Angel Town 3- new idle games',
#  'Monster Battles: TCG',
#  'Banana Market',
#  'Business Superstar Idle Tycoon',
#  'Impossible Bottle Flip!',
#  '"SellFee - Money\'s Just a Game"',
#  'Infinite Zombie Idle',
#  'Quiz for Fortnite Pros',
#  'Flirt Balls - Hello To Love !',
#  'Chaos Battle League',
#  '1942 Pacific Front',
#  'Shining Force Classics',
#  'Unlimited Skills Hero',
#  'MagicPenB',
#  'Infinite Knights',
#  'Bubble Bird 2019',
#  '"Donald\'s Domination - Build your Empire in Match 3"',
#  'Parchisi STAR',
#  'Idle Prison Tycoon Simulator',
#  'Parking Escape 2: Car Puzzle',
#  'Boom Day: card battle',
#  'Worm Battle: Wormageddon',
#  'Castle Fusion',
#  'Yokai: Spirits Hunt',
#  'Cool Sudoku, Jigsaw, Killer',
#  'Aquarium Idle',
#  'Fleet Command II',
#  'Lords of Kingdoms - War Order',
#  'Star Quest: TCG',
#  'Iron Marines Stickers',
#  'Hopeless Land: For Survival',
#  'That Donut Game',
#  'Pikes.io Brutal Squad',
#  'Video Game Tycoon: Tap Story',
#  'Idle Zoo Tycoon 3D',
#  '"King\'s Cross"',
#  'My Burger Shop 2',
#  'Gem Blast Match-3 Puzzle Crush',
#  'Heroes of Flatlandia',
#  'Idle Space Dynasty',
#  'War of Valkyrie',
#  'Army Men Strike: Toy Soldiers',
#  'Rainbow Smash: a Tile Thriller',
#  'Minecraft: Papercraft Studio',
#  'Cookie Clickers 2',
#  'Tappy Taco',
#  'CrazyBall  Match 5 - HaFun',
#  'Alienum: The Strategy War Game',
#  'Battle of Warship: War of Navy',
#  'XeeWar',
#  'Warriors Of Fate\\uff1aOnline',
#  'Kahuna',
#  'Factory Madness: Build It',
#  'Lake Kindred Origin',
#  'Weather Battle',
#  '"Jean\'s Sundaeria : Tap Dash"',
#  'Make a City Idle Tycoon',
#  'Fishing Travelers - Hello Fish',
#  'Stickman Unknown Battlegrounds',
#  'Checkers \\u2023',
#  'Total Sudoku',
#  'DEAD 2048',
#  'Red Empire2 - War Alert',
#  'Couple Game: Relationship Quiz',
#  'Battle Blobs: 3v3 Multiplayer',
#  'Cartoon Craft',
#  'PATHBOOKS  Live your own story',
#  'Idle Coffee Corp',
#  'Gods Of Arena',
#  'Legend of Solgard',
#  'Jurassic Tribes',
#  'Laylo: Listen, Share, Chat',
#  'Cooking Madness-Kitchen Frenzy',
#  'Sharks Vs Pineapples TicTacToe',
#  'Hero Park',
#  'Tower Defense: Final Battle',
#  'AirportPRG',
#  'Arena Stars: Battle Heroes',
#  'Rust RCon',
#  'Cubesolver by Yariv Gdidi',
#  'Minesweeper (With Multiplayer)',
#  'Epic War - Castle Alliance',
#  'Christmas Crush 2018 Xmas Game',
#  'Capital Fun!',
#  'Secret Palace Escape',
#  'Illuminati Adventure',
#  'Spill Zone',
#  'Draw A Tower',
#  'My Coffee Shop - Cafeteria',
#  'Jamata Tower Defense PE Lite',
#  'Mobile Legends: Adventure',
#  'Castle Crush: Epic Card Games',
#  '"Papa\'s Donuteria To Go!"',
#  'Stranded Critters Puzzle',
#  'Nexomon',
#  'Brew Town',
#  'Mancala.',
#  '#MySelfieStory: 100M Followers',
#  'Expert Sudoku Book',
#  'Conceptis Cross-a-Pix',
#  'Bubble Shooter - Pop Puzzle',
#  'Famous Factory Tycoon',
#  'Gravity Orange 2 Lite',
#  'World of Words - Word Game',
#  'Xtreme 3T Tic Tac Toe',
#  'SwipeOut \\xb7 Swipe Game',
#  'Arkon: Chess Opening Explorer',
#  'Clash of Age: Zombies Game',
#  'Stupid Test - Brainteasers, Trivia, and Logic',
#  'Cake Crush - Match 3 Game',
#  'Make it Big in Hollywood',
#  'Ultimate Alien Defense',
#  'Royal Chaos',
#  'Art of Defense - Tower defense',
#  'My Cafe Story',
#  'Tower Defense Generals TD',
#  'Wicked OZ Puzzle',
#  'Chef Yummy',
#  'Strike of Nations | WW3 MMO',
#  'Bridge Scoring',
#  'BlackJack Trainer 21',
#  'Neighbours Revenge',
#  'Crazy Cooking Star Chef',
#  'Transformers TCG Companion App',
#  'Pipe Jewels\\u2122',
#  'Royal Offense',
#  'Marble Fly',
#  'OH~! My Office - Simulation',
#  'Idle Crypto Tycoon',
#  'World War: Idle Clicker',
#  'Clap',
#  'Idle Rockets',
#  'Business Inc. 3D Simulator',
#  'Equal 10 Lite',
#  'Stickman Army : The Defenders',
#  'PUBG DEBRIEF',
#  'Pizza Inc: Tycoon delivery sim',
#  'City Car Wash Gas Station',
#  'Hidden Objects Easter Gardens',
#  '"Jean\'s Boutique Deluxe"',
#  'Mildly Interesting RTS',
#  'Blades Of Battle: Blood Bros',
#  'Dragon Trainer: Online Battle',
#  'Stock Master: realtime stocks',
#  'Idle Miner Tycoon: Cash Empire',
#  'Youtubers Life: Gaming Channel',
#  '"Don\'t Fall! Human Flat Gang 3D"',
#  'Tower Defense - Mutant Octopus',
#  'Dino Evolution',
#  '3D Beach Volleyball Finger Juggle',
#  'Block Fortress: Empires',
#  'Skin Creator 3D for Minecraft',
#  'Pok\\xe9mon GO',
#  'Cookie Wars\\u2122',
#  'Death Zombie: Street Kill',
#  'Genius Puzzles',
#  'Six Ages: Ride Like the Wind',
#  'Merge Empire',
#  'Mafioso - Gangster Paradise',
#  '"Sally\'s Studio HD"',
#  'Majong',
#  'Clash of Diamonds: Match 3',
#  'Blustone 2',
#  'Idle Fish Factory',
#  'Bubble Shooter games 2018',
#  'Non-Stop Space Defense',
#  'Battle Islands',
#  'Transformers: Earth Wars',
#  'Castle Creeps TD',
#  'Wallpaper Pack for Fortnite',
#  'HockeyBattle',
#  'Lordz2.io Conquest',
#  'NBTD FreeCell',
#  '"Papa\'s Pancakeria HD"',
#  'Paradise City Island Sim',
#  'Robot Tactics \\u2013 Strategy JRPG',
#  'Sunflower Factory: Idle Tycoon',
#  'Candy Patrol: Lollipop Defense',
#  'Bubbly Walrus',
#  'Chef Craze - Food Cooking Game',
#  'Crazy Chef Cooking Games',
#  'Blox Defense: Hero Tower RPG',
#  'World War Arena',
#  'Sea Game: Mega Carrier',
#  'Picky Pizza',
#  'Warhands: Epic clash PvP game',
#  'Antiquitas',
#  'Cooking Trip',
#  'Brave Conquest',
#  'Ready Up for League of Legends',
#  'Rock Paper Scissors iMessage',
#  'Lordz.io - Medieval PvP Battle',
#  '"Papa\'s Cupcakeria To Go!"',
#  'JewelKing - Puzzle Legend',
#  'Box-Jump',
#  'Ludo - Parchis 3D',
#  'Post Office',
#  'Jewel Galaxy: Gem Match Puzzle',
#  'Katy & Bob: Our Safari Caf\\xe9',
#  'PAC-MAN Pop',
#  'Cooking Dash\\u2122',
#  'Idle Frontier: Tap Tap Town',
#  'Food Truck Idle',
#  'Gnomes Garden: The Lost King',
#  'Go Classic Chinese Game',
#  'MaxDominator',
#  'Over Space',
#  'Egg Factory - Idle Tycoon',
#  'Tap Pets Hotel - Idle \\u0421licker',
#  'Archimedes: Eureka!',
#  'Survival: Wasteland Zombie',
#  'Tower Wars TD',
#  'Co Tuong, Co Up Online - Ziga',
#  'Cooking Frenzy: Cooking Games',
#  'Chess Tiger Pro',
#  'Car Merger',
#  'RISK: Global Domination',
#  'Friday the 13th: Killer Puzzle',
#  'Tower Blocks Puzzle',
#  'Tap Tap Trillionaire : Invest!',
#  'Diamond Miner Tycoon',
#  'Idle Space: Tycoon',
#  'Rocket War: Clash in the Fog',
#  'War Dragons',
#  'Warship Hunter',
#  'Catanerator - Map Generator',
#  'Ingress Prime',
#  'Patterns for Magic Cube',
#  'X-War:Clash of Zombies',
#  'Hidden Object Christmas Puzzle',
#  'Divide Numbers',
#  'Conceptis Block-a-Pix',
#  'Cellular Corps',
#  'Hidden Object Countryside Love',
#  'Flick Arena',
#  'Chess Tiger Lite',
#  'Catch Idle - Epic Clicker RPG',
#  'Asymmetric',
#  'Tutorial for ROBLOX',
#  'Crazy Defense Heroes',
#  'Dominoes Challenge',
#  'Crazy Kitchen Cooking',
#  'Trump Tycoon : Politics Game',
#  'Jump Numbers',
#  'Tower Knights!',
#  'World at Arms',
#  'Wild Clash: Online Battle',
#  'Potato baron - idle tycoon',
#  'Hidden Object Valentines Day',
#  'Amateur Surgeon 4',
#  'Bid Wars: Pawn Empire',
#  'Maria Way Youtube Blogger Game',
#  'Spider Solitaire 2 HD',
#  'Grand Bubble Shoot',
#  'Chess Friends - Play Online',
#  'Army Sniper Pro: Gun War Actio',
#  'Tower Crush: Strategy War Game',
#  'Age of Giants: Tribal Warlords',
#  'Battlefield Mission',
#  'NBTD Solitaire',
#  'Idle Cafe Tycoon - Tap Story',
#  'We Are Illuminati - Clicker',
#  'Robot Warfare: Mech Battle',
#  'Spellstone',
#  'Long Ago: Medieval Kingdoms',
#  'Crazy Rolling Hero',
#  'Critter Clash\\u2014Slingshot Battle',
#  'Grand Stickman: Missions Gangt',
#  '"King\'s League: Odyssey"',
#  'Battle Simulator 2',
#  'Space Idle',
#  'GhostRevenge',
#  'Underworld Football Manager 19',
#  'Five Dice!',
#  'Dessert Cooking Cake Maker',
#  'Super Match2 Blast',
#  '20 Squares: Royal Game of Ur',
#  'Cash, Inc. Fame & Fortune Game',
#  'Final Heroes',
#  'Top Drives \\u2013 Car Cards Racing',
#  'Brown Dust',
#  'Great Voyage:strategy war game',
#  'Line 98 - Lines 98',
#  'Cookie Clickers',
#  'Fish Farm 3 - Aquarium',
#  'Cooking Craze- Restaurant Game',
#  'Oh Marbles! A Simple Old Game',
#  'Drive on Moscow',
#  'Prison Break-Escape Game',
#  'Pocket Trains',
#  'Chezz: Play Fast Chess',
#  'Toy Crush Block Puzzle Games',
#  'Land Air Sea Warfare HD RTS',
#  'Land Air Sea Warfare',
#  'Slots GoldenHoYeah-CasinoSlots',
#  'Bridge Maker 2 - Railway Build',
#  '"Sally\'s Studio"',
#  '"Settler\'s Trail - Build a town"',
#  'Fill the Bucket.',
#  'Domination: Earth',
#  'Idle Smartphone Tycoon Mobile',
#  'Griblers',
#  'Catanous - Catan Generator',
#  '"Freakin\' Swimmin\' Duck"',
#  'SmartGo Player',
#  'Hotel Dracula - A Dash Game',
#  'Cook It!\\u2122 - Chef Cooking Games',
#  'Bloody Roads, California',
#  'Commander At War-New Rival',
#  'Taptap Heroes - Idle RPG',
#  'TowerMadness HD',
#  'Big Oil - Clicker Tycoon Game',
#  'Call Me Emperor',
#  'Mobile Legends: Bang Bang',
#  'Lines 98 Flat Classic',
#  'Virtual Families: Cook Off',
#  'Pocket Cube Solver',
#  'Solitaire \\u25bb Spiderette',
#  'TheBench',
#  'Star Command',
#  'CanCan The Game',
#  'Lumberwhack: Defend the Wild',
#  'Zlax.io Zombs Luv Ax',
#  'Slime Defense - Idle TD',
#  'Farm Clan\\xae',
#  'Mystery Math Town for iPhone',
#  'Mystery Math Town',
#  'Break the Jail: Escape Prison',
#  'Survival Arena\\u2122 TD',
#  ...]

# %%
from matplotlib.pyplot import imshow

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
def visualize_image_sim():
    app = input('Please Specify an App')
    print('---' * 8)
    
    ratio = dat.Name.apply(lambda x: similar(app,x))
    top_3 = list(ratio.sort_values(ascending=False).index[0:3])
    top_3_names = dat.iloc[top_3].Name.values
    
    
    app_refine = input('The most similar items in this set are ' + 
                      ', '.join(top_3_names) +' please specify which you are interested in')
    
    print('---' * 8)
    print('Looking for ' + app_refine)
    print('---' * 8)
    
    while (app_refine not in top_3_names) and (app_refine != 'end'):
        app_refine = input('Exact match not found, please specify the exact app' + 
                      ', '.join(top_3_names))
        
    if app_refine == 'end':
        print('ending process')
        return
    
    
    print('Icon for chosen App will be Displayed in pop-up')
    
    curr_image = Image.open(BytesIO(dat[dat.Name == app_refine].image_bytes.values[0]))
    
    curr_image.show()
    
    print('---' * 8)
    print('Gathering Similar Images')
    print('---' * 8)
    
    res = dif_percentage_lst(dat[dat.Name == app_refine].image_bytes.values[0], dat.dropna().image_bytes.values)
    
    
    best_images = gather_names(dat.dropna(),list(pd.Series(res).sort_values().index),'Name')[1:4]
    
    print('Top image similarities are ' + ', '.join(best_images))
    print('---' * 8)
    
    view = input('Would you like to view the images? Y/N')
    print('---' * 8)
    
    if view == 'Y':
        for i in best_images:
            similar_image = Image.open(BytesIO(dat[dat.Name == i].image_bytes.values[0]))
            similar_image.show()
    
    print('Images displayed')
    
    return ratio

# %%
rat = visualize_image_sim()
# Out:
# Please Specify an AppSudoku
# ------------------------
# The most similar items in this set are Sudoku, Clash of Legends: Heroes, Sea Jurassic Craft please specify which you are interested inSudoku
# ------------------------
# Looking for Sudoku
# ------------------------
# Icon for chosen App will be Displayed in pop-up
# ------------------------
# Gathering Similar Images
# ------------------------
# Top image similarities are Wooden Block Puzzle - Extreme, Bricks of Rome, Marble Solitaire : Peg Game
# ------------------------
# Would you like to view the images? Y/NY
# ------------------------
# Images displayed

# %% [markdown]
# # P2 - Similarity by current fields

# %%
text_sim_set = dat.copy()

# %% [markdown]
# ### Prep data for algo

# %%
from sklearn.cluster import KMeans

# %%
text_sim_set.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date',
#        'true_free', 'curr_release_date', 'time_since_update', 'image_bytes',
#        'parsed_desc'],
#       dtype='object')

# %%
text_sim_set[['Name', 'Subtitle', 'Average User Rating',
       'User Rating Count', 'Price', 'In-app Purchases',
       'Age Rating', 'Languages', 'Primary Genre',
       'Genres',
       'true_free', 'time_since_update',
       'parsed_desc']].head()
# Out:
#             Name Subtitle  Average User Rating  User Rating Count  Price  \
# 0         Sudoku     None                  4.0             3553.0   2.99
# 1        Reversi     None                  3.5              284.0   1.99
# 2        Morocco     None                  3.0             8376.0   0.00
# 3  Sudoku (Free)     None                  3.5           190394.0   0.00
# 4   Senet Deluxe     None                  3.5               28.0   2.99
#
#   In-app Purchases Age Rating  \
# 0                0         4+
# 1                0         4+
# 2                0         4+
# 3                0         4+
# 4                0         4+
#
#                                                             Languages  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES, SV, ZH
# 1                                                                  EN
# 2                                                                  EN
# 3  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES, SV, ZH
# 4          DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU, ZH, ES, SV
#
#   Primary Genre                             Genres  true_free  \
# 0         Games            Games, Strategy, Puzzle      False
# 1         Games             Games, Strategy, Board      False
# 2         Games             Games, Board, Strategy       True
# 3         Games            Games, Strategy, Puzzle       True
# 4         Games  Games, Strategy, Board, Education      False
#
#    time_since_update  \
# 0              887.0
# 1              535.0
# 2              789.0
# 3              887.0
# 4              469.0
#
#                                                                                            parsed_desc
# 0  Join over 21,000,000 of our fans and download one of our Sudoku games today! Makers of the Best ...
# 1  The classic game of Reversi, also known as Othello, is a much-loved strategy board game. It is o...
# 2  Play the classic strategy game Othello (also known as Reversi) on your iPhone or iPod Touch. The...
# 3  Top 100 free app for over a year. Rated "Best Sudoku Game of the Year" by Apple. Rated #9 Game o...
# 4  "Senet Deluxe - The Ancient Game of Life and Afterlife Senet is an ancient Egyptian race game an...

# %%
# From string to list
text_sim_set.Languages = text_sim_set.Languages.apply(lambda x: x.split(', ') if x is not None else None)
text_sim_set.Genres = text_sim_set.Genres.apply(lambda x: x.split(', ') if x is not None else None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ec3c64761c76> in <module>()
#       1 # From string to list
# ----> 2 text_sim_set.Languages = text_sim_set.Languages.apply(lambda x: x.split(', ') if x is not None else None)
#       3 text_sim_set.Genres = text_sim_set.Genres.apply(lambda x: x.split(', ') if x is not None else None)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-8-ec3c64761c76> in <lambda>(x)
#       1 # From string to list
# ----> 2 text_sim_set.Languages = text_sim_set.Languages.apply(lambda x: x.split(', ') if x is not None else None)
#       3 text_sim_set.Genres = text_sim_set.Genres.apply(lambda x: x.split(', ') if x is not None else None)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
feats = pd.concat([text_sim_set[['Average User Rating',
       'User Rating Count', 'Price','true_free','time_since_update']],
                  pd.get_dummies(text_sim_set.Languages.apply(pd.Series).stack()).sum(level=0),
                 pd.get_dummies(text_sim_set.Genres.apply(pd.Series).stack()).sum(level=0)],
                  axis = 1)

# %% [markdown]
# Look into nulls which would interfere with modeling

# %%
(feats.isna().mean().round(4) * 100).sort_values()
# Out:
# Word                    0.00
# Lifestyle               0.00
# Kids & Family           0.00
# Health & Fitness        0.00
# Gaming                  0.00
#                        ...
# LA                      0.36
# LO                      0.36
# KM                      0.36
# User Rating Count      55.55
# Average User Rating    55.55
# Length: 167, dtype: float64

# %% [markdown]
# Only a few columns with significant nulls, User Ratings Count and Average User Rating. It would make sense to repalce these with 0 since that is actually what null would refer to.
#
# Additionally, all other features are sparse and can be replaced with 0 as well.

# %%
feats.fillna(value=0, inplace=True)

# %% [markdown]
# Find optimal number of clusters

# %%
# calculate distortion for a range of number of cluster
distortions = []
for i in range(1, 20):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=25, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(feats)
    distortions.append(km.inertia_)

# %%
plt.plot(range(1, 20), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %% [markdown]
# Looks like ~5 clusters is ideal for this

# %%
km = KMeans(
    n_clusters=5, init='random',
    n_init=25, max_iter=300, 
    tol=1e-04, random_state=6
)
y_km = km.fit_predict(feats)

# %% [markdown]
# Add back into main df

# %%
text_sim_set['cluster'] = y_km

# %% [markdown]
# Look into how well this did through more visualizations

# %%
text_sim_set[text_sim_set['User Rating Count'] < 100000]['cluster'].nunique()
# Out:
# 2

# %%
sns.relplot(x="User Rating Count", y="Average User Rating", hue="cluster", size="Price",
            sizes=(40, 400), alpha=.5,
            palette = sns.color_palette("Set2", n_colors = 2),
            height=6, data=text_sim_set[text_sim_set['User Rating Count'] < 100000])
plt.show()

# %%
text_sim_set.cluster.value_counts()
# Out:
# 0    16729
# 3       93
# 2       22
# 4        2
# 1        1
# Name: cluster, dtype: int64

# %% [markdown]
# ### Unfortunately, most put into the same cluster which is not particularly useful. Can see clear segmentation based off of the count of user ratings which accounts for 99% of the data with the remaining 1% being apps with far more ratings than average

# %% [markdown]
# Will look at removing the feature causing this segmentation and redo the process

# %%
# calculate distortion for a range of number of cluster
distortions = []
for i in range(1, 20):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(feats[list(feats.columns)[:1] + list(feats.columns)[2:]])
    distortions.append(km.inertia_)

# %%
plt.plot(range(1, 20), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %% [markdown]
# 5 still seems fine

# %%
km = KMeans(
    n_clusters=5, init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=0
)
y_km_2 = km.fit_predict(feats[list(feats.columns)[:1] + list(feats.columns)[2:]])

# %%
text_sim_set['cluster_2'] = y_km_2

# %%
text_sim_set.cluster_2.value_counts()
# Out:
# 4    5625
# 0    4352
# 3    3966
# 2    2331
# 1     573
# Name: cluster_2, dtype: int64

# %%
sns.relplot(x="User Rating Count", y="Average User Rating", hue="cluster_2", size="Price",
            sizes=(40, 400), alpha=.5,
            palette = sns.color_palette("muted", n_colors = text_sim_set[text_sim_set['User Rating Count'] < 10000].cluster_2.nunique()),
            height=6, data=text_sim_set[text_sim_set['User Rating Count'] < 100000])
plt.show()

# %%
text_sim_set.head()
# Out:
#                                                       URL         ID  \
# 0        https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1       https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2       https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3   https://apps.apple.com/us/app/sudoku-free/id285755462  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id285831220  285831220
#
#             Name Subtitle  \
# 0         Sudoku     None
# 1        Reversi     None
# 2        Morocco     None
# 3  Sudoku (Free)     None
# 4   Senet Deluxe     None
#
#                                                                                               Icon URL  \
# 0  https://is2-ssl.mzstatic.com/image/thumb/Purple127/v4/7d/23/c6/7d23c660-aba8-308a-05c0-19385a377...
# 1  https://is4-ssl.mzstatic.com/image/thumb/Purple128/v4/f7/e8/10/f7e810c8-72b4-cd85-e2d3-fbcb1e3ef...
# 2  https://is5-ssl.mzstatic.com/image/thumb/Purple118/v4/98/b2/41/98b241cc-29b7-5f67-0060-1e030f355...
# 3  https://is3-ssl.mzstatic.com/image/thumb/Purple117/v4/64/da/aa/64daaaa4-40b5-9e9f-9d60-b936b5d2f...
# 4  https://is1-ssl.mzstatic.com/image/thumb/Purple118/v4/ab/2d/cf/ab2dcfe6-2178-6f74-2d42-0b6db66fc...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# 0                  4.0             3553.0   2.99                0
# 1                  3.5              284.0   1.99                0
# 2                  3.0             8376.0   0.00                0
# 3                  3.5           190394.0   0.00                0
# 4                  3.5               28.0   2.99                0
#
#                                                                                            Description  \
# 0  Join over 21,000,000 of our fans and download one of our Sudoku games today!\n\nMakers of the Be...
# 1  The classic game of Reversi, also known as Othello, is a much-loved strategy board game. It is o...
# 2  Play the classic strategy game Othello (also known as Reversi) on your iPhone or iPod Touch. The...
# 3  Top 100 free app for over a year.\nRated "Best Sudoku Game of the Year" by Apple.\nRated #9 Game...
# 4  "Senet Deluxe - The Ancient Game of Life and Afterlife\n\nSenet is an ancient Egyptian race game...
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
# 2               Bayou Games         4+
# 3  Mighty Mighty Good Games         4+
# 4           RoGame Software         4+
#
#                                                               Languages  \
# 0  [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES, SV, ZH]
# 1                                                                  [EN]
# 2                                                                  [EN]
# 3  [DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT, RU, ZH, ES, SV, ZH]
# 4          [DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU, ZH, ES, SV]
#
#          Size Primary Genre                               Genres  \
# 0  15853568.0         Games            [Games, Strategy, Puzzle]
# 1  12328960.0         Games             [Games, Strategy, Board]
# 2    674816.0         Games             [Games, Board, Strategy]
# 3  21552128.0         Games            [Games, Strategy, Puzzle]
# 4  34689024.0         Games  [Games, Strategy, Board, Education]
#
#   Original Release Date Current Version Release Date  true_free  \
# 0            11/07/2008                   30/05/2017      False
# 1            11/07/2008                   17/05/2018      False
# 2            11/07/2008                    5/09/2017       True
# 3            23/07/2008                   30/05/2017       True
# 4            18/07/2008                   22/07/2018      False
#
#   curr_release_date  time_since_update  \
# 0        2017-05-30              887.0
# 1        2018-05-17              535.0
# 2        2017-09-05              789.0
# 3        2017-05-30              887.0
# 4        2018-07-22              469.0
#
#                                                                                            image_bytes  \
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
# 2  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x02\x00\x1c\x00\x1c\x00\x00\xff\xdb\x00C\x00\x06\x04\...
# 3  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xdb\x00C\x00\x06\x04\x05\x0...
# 4  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xe1\x00hExif\x00\x00MM\x00*...
#
#                                                                                            parsed_desc  \
# 0  Join over 21,000,000 of our fans and download one of our Sudoku games today! Makers of the Best ...
# 1  The classic game of Reversi, also known as Othello, is a much-loved strategy board game. It is o...
# 2  Play the classic strategy game Othello (also known as Reversi) on your iPhone or iPod Touch. The...
# 3  Top 100 free app for over a year. Rated "Best Sudoku Game of the Year" by Apple. Rated #9 Game o...
# 4  "Senet Deluxe - The Ancient Game of Life and Afterlife Senet is an ancient Egyptian race game an...
#
#                                                                                          cleansed_desc  \
# 0  [Join, 21,000,000, fans, download, Sudoku, games, today, !, Makers, Best, Sudoku, Game, 2008, ,,...
# 1  [classic, game, Reversi, ,, known, Othello, ,, -, loved, strategy, board, game, ., described, ta...
# 2  [Play, classic, strategy, game, Othello, (, known, Reversi, ), iPhone, iPod, Touch, ., object, f...
# 3  [100, free, app, year, ., Rated, ", Best, Sudoku, Game, Year, ", Apple, ., Rated, #, 9, Game, Ye...
# 4  [", Senet, Deluxe, -, Ancient, Game, Life, Afterlife, Senet, ancient, Egyptian, race, game, pred...
#
#                                                                                             spacy_text  \
# 0  [Join, fans, download, Sudoku, games, today, Makers, Best, Sudoku, Game, Sudoku, Free, offer, be...
# 1  [classic, game, Reversi, known, Othello, loved, strategy, board, game, described, taking, minute...
# 2  [Play, classic, strategy, game, Othello, known, Reversi, iPhone, iPod, Touch, object, finish, ga...
# 3  [free, app, year, Rated, Best, Sudoku, Game, Year, Apple, Rated, Game, Year, Apple, Rated, App, ...
# 4  [Senet, Deluxe, Ancient, Game, Life, Afterlife, Senet, ancient, Egyptian, race, game, predecesso...
#
#                                                                                       desc_parsed_text  \
# 0  [join, fan, download, sudoku, game, today, maker, best, sudoku, game, sudoku, free, offer, good,...
# 1  [classic, game, reversi, know, othello, love, strategy, board, game, describe, take, minute, lea...
# 2  [play, classic, strategy, game, othello, know, reversi, iphone, ipod, touch, object, finish, gam...
# 3  [free, app, year, rate, best, sudoku, game, year, apple, rate, game, year, apple, rate, app, yea...
# 4  [senet, deluxe, ancient, game, life, afterlife, senet, ancient, egyptian, race, game, predecesso...
#
#                                                                                        desc_parsed_pos  \
# 0  [VERB, NOUN, VERB, PROPN, NOUN, NOUN, NOUN, PROPN, PROPN, PROPN, PROPN, PROPN, VERB, ADJ, VERB, ...
# 1  [ADJ, NOUN, PROPN, VERB, PROPN, VERB, NOUN, NOUN, NOUN, VERB, VERB, NOUN, VERB, NOUN, NOUN, NOUN...
# 2  [VERB, ADJ, NOUN, NOUN, PROPN, VERB, PROPN, PROPN, PROPN, PROPN, NOUN, VERB, NOUN, NOUN, NOUN, N...
# 3  [ADJ, NOUN, NOUN, VERB, PROPN, PROPN, PROPN, NOUN, PROPN, VERB, PROPN, PROPN, PROPN, VERB, NOUN,...
# 4  [PROPN, PROPN, PROPN, PROPN, PROPN, PROPN, PROPN, ADJ, ADJ, NOUN, NOUN, NOUN, ADJ, PROPN, ADJ, V...
#
#                                                                                       desc_parsed_ents  \
# 0  [ORG, GPE, DATE, ORG, ORG, ORG, GPE, NORP, GPE, TIME, GPE, PERSON, PERSON, CARDINAL, ORG, ORG, P...
# 1                                                          [ORG, PERSON, TIME, TIME, ORG, PERSON, ORG]
# 2                                                                     [PERSON, PERSON, PERSON, PERSON]
# 3  [DATE, DATE, ORG, MONEY, ORG, DATE, ORG, GPE, GPE, PERSON, PERSON, ORG, ORG, ORG, GPE, PERSON, P...
# 4  [NORP, GPE, PERSON, PERSON, GPE, PERSON, NORP, ORG, ORG, ORG, PERSON, ORG, NORP, ORG, ORG, PERSO...
#
#    cluster  cluster_2  hier_cluster
# 0        0          0             1
# 1        0          0             1
# 2        0          0             1
# 3        2          0             0
# 4        0          4             1

# %%
text_sim_set[text_sim_set['User Rating Count'] < 10000].cluster_2.nunique()
# Out:
# 5

# %% [markdown]
# Try different clustering methods

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
clustering = AgglomerativeClustering(n_clusters=5).fit(feats)

# %%
hier_cluster = clustering.fit_predict(feats)

# %%
text_sim_set['hier_cluster'] = hier_cluster

# %%
text_sim_set.hier_cluster.value_counts()
# Out:
# 1    16672
# 2      150
# 0       23
# 4        1
# 3        1
# Name: hier_cluster, dtype: int64

# %% [markdown]
# ## Leverage a word cloud to show differences between best games and the rest

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text_sim_set['spacy_text'] = text_sim_set.parsed_desc.apply(lambda x: [i for i in nlp(x) if (i.is_stop == False 
                                                                                                and i.is_alpha == True)])

# %%
text_sim_set['desc_parsed_text'] = text_sim_set.spacy_text.apply(lambda x: [i.lemma_.lower() for i in x])

# %%
text_sim_set['desc_parsed_pos'] = text_sim_set.spacy_text.apply(lambda x: [i.pos_ for i in x])

# %%
text_sim_set['desc_parsed_ents'] = text_sim_set.spacy_text.apply(lambda x: 
                                                                 [i.ent_type_ for i in x if i.ent_type_ != ''])

# %%
text_sim_set.to_csv('text_sim_set.csv')

# %%
text_sim_set = pd.read_csv('text_sim_set.csv')

# %%
text_sim_set.head()
# Out:
#    Unnamed: 0                                                URL         ID  \
# 0           0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1           1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2           2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3           3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4           4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  ...  \
# 0                  4.0             3553.0   2.99                0  ...
# 1                  3.5              284.0   1.99                0  ...
# 2                  3.0             8376.0   0.00                0  ...
# 3                  3.5           190394.0   0.00                0  ...
# 4                  3.5               28.0   2.99                0  ...
#
#   true_free curr_release_date time_since_update  \
# 0     False        2017-05-30             887.0
# 1     False        2018-05-17             535.0
# 2      True        2017-09-05             789.0
# 3      True        2017-05-30             887.0
# 4     False        2018-07-22             469.0
#
#                                          image_bytes  \
# 0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 2  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x02...
# 3  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01...
# 4  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
#
#                                          parsed_desc  \
# 0  Join over 21,000,000 of our fans and download ...
# 1  The classic game of Reversi, also known as Oth...
# 2  Play the classic strategy game Othello (also k...
# 3  Top 100 free app for over a year. Rated "Best ...
# 4  "Senet Deluxe - The Ancient Game of Life and A...
#
#                                        cleansed_desc  \
# 0  [Join, 21,000,000, fans, download, Sudoku, gam...
# 1  [classic, game, Reversi, ,, known, Othello, ,,...
# 2  [Play, classic, strategy, game, Othello, (, kn...
# 3  [100, free, app, year, ., Rated, ", Best, Sudo...
# 4  [", Senet, Deluxe, -, Ancient, Game, Life, Aft...
#
#                                           spacy_text  \
# 0  [Join, fans, download, Sudoku, games, today, M...
# 1  [classic, game, Reversi, known, Othello, loved...
# 2  [Play, classic, strategy, game, Othello, known...
# 3  [free, app, year, Rated, Best, Sudoku, Game, Y...
# 4  [Senet, Deluxe, Ancient, Game, Life, Afterlife...
#
#                                     desc_parsed_text  \
# 0  ['join', 'fan', 'download', 'sudoku', 'game', ...
# 1  ['classic', 'game', 'reversi', 'know', 'othell...
# 2  ['play', 'classic', 'strategy', 'game', 'othel...
# 3  ['free', 'app', 'year', 'rate', 'best', 'sudok...
# 4  ['senet', 'deluxe', 'ancient', 'game', 'life',...
#
#                                      desc_parsed_pos  \
# 0  ['VERB', 'NOUN', 'VERB', 'PROPN', 'NOUN', 'NOU...
# 1  ['ADJ', 'NOUN', 'PROPN', 'VERB', 'PROPN', 'VER...
# 2  ['VERB', 'ADJ', 'NOUN', 'NOUN', 'PROPN', 'VERB...
# 3  ['ADJ', 'NOUN', 'NOUN', 'VERB', 'PROPN', 'PROP...
# 4  ['PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', ...
#
#                                     desc_parsed_ents
# 0  ['ORG', 'GPE', 'DATE', 'ORG', 'ORG', 'ORG', 'G...
# 1  ['ORG', 'PERSON', 'TIME', 'TIME', 'ORG', 'PERS...
# 2           ['PERSON', 'PERSON', 'PERSON', 'PERSON']
# 3  ['DATE', 'DATE', 'ORG', 'MONEY', 'ORG', 'DATE'...
# 4  ['NORP', 'GPE', 'PERSON', 'PERSON', 'GPE', 'PE...
#
# [5 rows x 29 columns]

# %%
text_sim_set[text_sim_set['User Rating Count'] < 100000]
# Out:
#        Unnamed: 0                                                URL  \
# 0               0   https://apps.apple.com/us/app/sudoku/id284921427
# 1               1  https://apps.apple.com/us/app/reversi/id284926400
# 2               2  https://apps.apple.com/us/app/morocco/id284946595
# 4               4  https://apps.apple.com/us/app/senet-deluxe/id2...
# 5               5  https://apps.apple.com/us/app/sudoku-classic-n...
# ...           ...                                                ...
# 16790       16950  https://apps.apple.com/us/app/die-last/id14730...
# 16796       16956  https://apps.apple.com/us/app/basic-slosh/id14...
# 16802       16962  https://apps.apple.com/us/app/idle-racing-tyco...
# 16807       16967  https://apps.apple.com/us/app/glow-hockey-stri...
# 16833       16993  https://apps.apple.com/us/app/agadmator-chess-...
#
#                ID                            Name  \
# 0       284921427                          Sudoku
# 1       284926400                         Reversi
# 2       284946595                         Morocco
# 4       285831220                    Senet Deluxe
# 5       286210009  Sudoku - Classic number puzzle
# ...           ...                             ...
# 16790  1473084135                        Die Last
# 16796  1473181500                     Basic Slosh
# 16802  1473559573              Idle Racing Tycoon
# 16807  1473680543              Glow Hockey Strike
# 16833  1474461379           Agadmator Chess Clock
#
#                             Subtitle  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 4                                NaN
# 5            Original brain training
# ...                              ...
# 16790                Who can survive
# 16796                            NaN
# 16802    Develop Your Car Racing Inc
# 16807  Best 2 player air hockey game
# 16833   Simple & elegant chess clock
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 5      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# ...                                                  ...                  ...
# 16790  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 16796  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16802  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16807  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16833  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
#
#        User Rating Count  Price In-app Purchases  ... true_free  \
# 0                 3553.0   2.99                0  ...     False
# 1                  284.0   1.99                0  ...     False
# 2                 8376.0   0.00                0  ...      True
# 4                   28.0   2.99                0  ...     False
# 5                   47.0   0.00             1.99  ...     False
# ...                  ...    ...              ...  ...       ...
# 16790                6.0   0.00                0  ...      True
# 16796               30.0   0.00                0  ...      True
# 16802               51.0   0.00                0  ...      True
# 16807                5.0   0.00                0  ...      True
# 16833               33.0   0.00                0  ...      True
#
#       curr_release_date time_since_update  \
# 0            2017-05-30             887.0
# 1            2018-05-17             535.0
# 2            2017-09-05             789.0
# 4            2018-07-22             469.0
# 5            2019-04-29             188.0
# ...                 ...               ...
# 16790        2019-07-31              95.0
# 16796        2019-07-23             103.0
# 16802        2019-07-31              95.0
# 16807        2019-07-28              98.0
# 16833        2019-07-30              96.0
#
#                                              image_bytes  \
# 0      b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 1      b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 2      b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x02...
# 4      b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 5      b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# ...                                                  ...
# 16790  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 16796  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 16802  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 16807  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 16833  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
#
#                                              parsed_desc  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# 5      Sudoku will tease your brain, challenge you or...
# ...                                                  ...
# 16790  "Welcome to this mysterious room full of gears...
# 16796  "Take the ball to safety and reach the next le...
# 16802  Build your racing circuit. Recruit visitors, u...
# 16807  Glow Hockey Strike is a cool colorful air hock...
# 16833  Agadmator Chess Clock is a beautiful, lightwei...
#
#                                            cleansed_desc  \
# 0      [Join, 21,000,000, fans, download, Sudoku, gam...
# 1      [classic, game, Reversi, ,, known, Othello, ,,...
# 2      [Play, classic, strategy, game, Othello, (, kn...
# 4      [", Senet, Deluxe, -, Ancient, Game, Life, Aft...
# 5      [Sudoku, tease, brain, ,, challenge, allow, un...
# ...                                                  ...
# 16790  [", Welcome, mysterious, room, gears, traps, ....
# 16796  [", ball, safety, reach, level, ,, touch, plat...
# 16802  [Build, racing, circuit, ., Recruit, visitors,...
# 16807  [Glow, Hockey, Strike, cool, colorful, air, ho...
# 16833  [Agadmator, Chess, Clock, beautiful, ,, lightw...
#
#                                               spacy_text  \
# 0      [Join, fans, download, Sudoku, games, today, M...
# 1      [classic, game, Reversi, known, Othello, loved...
# 2      [Play, classic, strategy, game, Othello, known...
# 4      [Senet, Deluxe, Ancient, Game, Life, Afterlife...
# 5      [Sudoku, tease, brain, challenge, allow, unwin...
# ...                                                  ...
# 16790  [Welcome, mysterious, room, gears, traps, play...
# 16796  [ball, safety, reach, level, touch, platforms,...
# 16802  [Build, racing, circuit, Recruit, visitors, up...
# 16807  [Glow, Hockey, Strike, cool, colorful, air, ho...
# 16833  [Agadmator, Chess, Clock, beautiful, lightweig...
#
#                                         desc_parsed_text  \
# 0      ['join', 'fan', 'download', 'sudoku', 'game', ...
# 1      ['classic', 'game', 'reversi', 'know', 'othell...
# 2      ['play', 'classic', 'strategy', 'game', 'othel...
# 4      ['senet', 'deluxe', 'ancient', 'game', 'life',...
# 5      ['sudoku', 'tease', 'brain', 'challenge', 'all...
# ...                                                  ...
# 16790  ['welcome', 'mysterious', 'room', 'gear', 'tra...
# 16796  ['ball', 'safety', 'reach', 'level', 'touch', ...
# 16802  ['build', 'racing', 'circuit', 'recruit', 'vis...
# 16807  ['glow', 'hockey', 'strike', 'cool', 'colorful...
# 16833  ['agadmator', 'chess', 'clock', 'beautiful', '...
#
#                                          desc_parsed_pos  \
# 0      ['VERB', 'NOUN', 'VERB', 'PROPN', 'NOUN', 'NOU...
# 1      ['ADJ', 'NOUN', 'PROPN', 'VERB', 'PROPN', 'VER...
# 2      ['VERB', 'ADJ', 'NOUN', 'NOUN', 'PROPN', 'VERB...
# 4      ['PROPN', 'PROPN', 'PROPN', 'PROPN', 'PROPN', ...
# 5      ['PROPN', 'VERB', 'NOUN', 'VERB', 'VERB', 'VER...
# ...                                                  ...
# 16790  ['VERB', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NOUN'...
# 16796  ['NOUN', 'NOUN', 'VERB', 'NOUN', 'VERB', 'NOUN...
# 16802  ['VERB', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'VERB...
# 16807  ['PROPN', 'PROPN', 'PROPN', 'ADJ', 'ADJ', 'NOU...
# 16833  ['PROPN', 'PROPN', 'PROPN', 'ADJ', 'ADJ', 'NOU...
#
#                                         desc_parsed_ents
# 0      ['ORG', 'GPE', 'DATE', 'ORG', 'ORG', 'ORG', 'G...
# 1      ['ORG', 'PERSON', 'TIME', 'TIME', 'ORG', 'PERS...
# 2               ['PERSON', 'PERSON', 'PERSON', 'PERSON']
# 4      ['NORP', 'GPE', 'PERSON', 'PERSON', 'GPE', 'PE...
# 5      ['GPE', 'GPE', 'GPE', 'GPE', 'CARDINAL', 'PERS...
# ...                                                  ...
# 16790                                           ['TIME']
# 16796                                                 []
# 16802                                                 []
# 16807  ['PERSON', 'PERSON', 'PERSON', 'PERSON', 'PERS...
# 16833                                            ['ORG']
#
# [7448 rows x 29 columns]

# %%
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=6
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
high_scores = ' '.join(text_sim_set[text_sim_set['Average User Rating'] >= 4].desc_parsed_text.apply(lambda x: ' '.join(x)))
lower_scores = ' '.join(text_sim_set[text_sim_set['Average User Rating'] < 4].desc_parsed_text.apply(lambda x: ' '.join(x)))

# %%
show_wordcloud(high_scores)

# %%
show_wordcloud(lower_scores)

# %%
most_reviews = ' '.join(text_sim_set[text_sim_set['User Rating Count'] >= 250].desc_parsed_text.apply(lambda x: ' '.join(x)))
less_reviews = ' '.join(text_sim_set[text_sim_set['User Rating Count'] < 250].desc_parsed_text.apply(lambda x: ' '.join(x)))

# %%
show_wordcloud(most_reviews)

# %%
show_wordcloud(less_reviews)

# %%
for i in range(5):
    print('Cluster ' + str(i))
    show_wordcloud(' '.join(text_sim_set[text_sim_set.cluster_2 == i].desc_parsed_text.apply(lambda x: ' '.join(x))))
# Out:
# Cluster 0
# Cluster 1
# Cluster 2
# Cluster 3
# Cluster 4
